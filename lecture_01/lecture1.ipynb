# %% [markdown]
# # This is a Markdown cell
#
# ## This is a Markdown cell (slightly smaller)
#
# ## ## This is a Markdown cell (even smaller)

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# <font size = "10">
#
# This is font size 10
#
# <font size = "4" color = "red">
#
# This is font size 4 in red
